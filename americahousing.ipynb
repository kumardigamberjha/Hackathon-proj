# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("C:/Users/Nitin Mittal/OneDrive/Desktop/data (5).csv")

# %%
print(df)
# Out:
#                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.head()
# Out:
#                date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  02-05-2014 00:00   313000.0         3       1.50         1340      7912
# 1  02-05-2014 00:00  2384000.0         5       2.50         3650      9050
# 2  02-05-2014 00:00   342000.0         3       2.00         1930     11947
# 3  02-05-2014 00:00   420000.0         3       2.25         2000      8030
# 4  02-05-2014 00:00   550000.0         4       2.50         1940     10500
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# 0     1.5           0     0          3        1340              0      1955
# 1     2.0           0     4          5        3370            280      1921
# 2     1.0           0     0          4        1930              0      1966
# 3     1.0           0     0          4        1000           1000      1963
# 4     1.0           0     0          4        1140            800      1976
#
# ...

# %%
df.tail()
# Out:
#                   date        price  bedrooms  bathrooms  sqft_living  \
# 4595  09-07-2014 00:00  308166.6667         3       1.75         1510
# 4596  09-07-2014 00:00  534333.3333         3       2.50         1460
# 4597  09-07-2014 00:00  416904.1667         3       2.50         3010
# 4598  10-07-2014 00:00  203400.0000         4       2.00         2090
# 4599  10-07-2014 00:00  220600.0000         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# 4595      6360     1.0           0     0          4        1510
# 4596      7573     2.0           0     0          3        1460
# 4597      7014     2.0           0     0          3        3010
# 4598      6630     1.0           0     0          3        1070
# 4599      8102     2.0           0     0          4        1490
#
#       sqft_basement  yr_built  yr_renovated             street       city  \
# 4595              0      1954          1979     501 N 143rd St    Seattle
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4600 entries, 0 to 4599
# Data columns (total 18 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   date           4600 non-null   object
#  1   price          4600 non-null   float64
#  2   bedrooms       4600 non-null   int64
#  3   bathrooms      4600 non-null   float64
#  4   sqft_living    4600 non-null   int64
#  5   sqft_lot       4600 non-null   int64
#  6   floors         4600 non-null   float64
#  7   waterfront     4600 non-null   int64
#  8   view           4600 non-null   int64
#  9   condition      4600 non-null   int64
#  10  sqft_above     4600 non-null   int64
#  11  sqft_basement  4600 non-null   int64
#  12  yr_built       4600 non-null   int64
#  13  yr_renovated   4600 non-null   int64
#  14  street         4600 non-null   object
#  15  city           4600 non-null   object
#  16  statezip       4600 non-null   object
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.describe()
# Out:
#               price     bedrooms    bathrooms   sqft_living      sqft_lot  \
# count  4.600000e+03  4600.000000  4600.000000   4600.000000  4.600000e+03
# mean   5.519630e+05     3.400870     2.160815   2139.346957  1.485252e+04
# std    5.638347e+05     0.908848     0.783781    963.206916  3.588444e+04
# min    0.000000e+00     0.000000     0.000000    370.000000  6.380000e+02
# 25%    3.228750e+05     3.000000     1.750000   1460.000000  5.000750e+03
# 50%    4.609435e+05     3.000000     2.250000   1980.000000  7.683000e+03
# 75%    6.549625e+05     4.000000     2.500000   2620.000000  1.100125e+04
# max    2.659000e+07     9.000000     8.000000  13540.000000  1.074218e+06
#
#             floors   waterfront         view    condition   sqft_above  \
# count  4600.000000  4600.000000  4600.000000  4600.000000  4600.000000
# mean      1.512065     0.007174     0.240652     3.451739  1827.265435
# std       0.538288     0.084404     0.778405     0.677230   862.168977
# ...

# %%
df.describe(include="all")
# Out:
#                     date         price     bedrooms    bathrooms  \
# count               4600  4.600000e+03  4600.000000  4600.000000
# unique                70           NaN          NaN          NaN
# top     23-06-2014 00:00           NaN          NaN          NaN
# freq                 142           NaN          NaN          NaN
# mean                 NaN  5.519630e+05     3.400870     2.160815
# std                  NaN  5.638347e+05     0.908848     0.783781
# min                  NaN  0.000000e+00     0.000000     0.000000
# 25%                  NaN  3.228750e+05     3.000000     1.750000
# 50%                  NaN  4.609435e+05     3.000000     2.250000
# 75%                  NaN  6.549625e+05     4.000000     2.500000
# max                  NaN  2.659000e+07     9.000000     8.000000
#
#          sqft_living      sqft_lot       floors   waterfront         view  \
# count    4600.000000  4.600000e+03  4600.000000  4600.000000  4600.000000
# ...

# %%
df.nunique()
# Out:
# date               70
# price            1741
# bedrooms           10
# bathrooms          26
# sqft_living       566
# sqft_lot         3113
# floors              6
# waterfront          2
# view                5
# condition           5
# sqft_above        511
# sqft_basement     207
# yr_built          115
# yr_renovated       60
# street           4525
# city               44
# statezip           77
# country             1
# dtype: int64

# %%
df.count
# Out:
# <bound method DataFrame.count of                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.shape
# Out:
# (4600, 18)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df.dropna(
)
# Out:
#                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df['street'].value_counts()
# Out:
# 2520 Mulberry Walk NE     4
# 2500 Mulberry Walk NE     3
# 9413 34th Ave SW          2
# 6008 8th Ave NE           2
# 11034 NE 26th Pl          2
#                          ..
# 1404 Broadmoor Dr E       1
# 3249 E Ames Lake Dr NE    1
# 6032 35th Ave NE          1
# 1006 NE Ravenna Blvd      1
# 18717 SE 258th St         1
# Name: street, Length: 4525, dtype: int64

# %%
x=df["bedrooms"]
y=df["price"]
plt.scatter(x,y)
plt.show()

# %%
x=df["bathrooms"]
y=df["price"]
plt.scatter(x,y)
plt.show()

# %%
df["bathrooms"]=df["bathrooms"].astype(int)

# %%
df["floors"]=df["floors"].astype(int)

# %%
df.dtypes
# Out:
# date              object
# price            float64
# bedrooms           int64
# bathrooms          int32
# sqft_living        int64
# sqft_lot           int64
# floors             int32
# waterfront         int64
# view               int64
# condition          int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# street            object
# city              object
# statezip          object
# country           object
# dtype: object

# %%
df=df.drop(["street","city","statezip","country"],axis=1)

# %%
print(df
     
     
     
     )
# Out:
#                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3          1         1340
# 1     02-05-2014 00:00  2.384000e+06         5          2         3650
# 2     02-05-2014 00:00  3.420000e+05         3          2         1930
# 3     02-05-2014 00:00  4.200000e+05         3          2         2000
# 4     02-05-2014 00:00  5.500000e+05         4          2         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3          1         1510
# 4596  09-07-2014 00:00  5.343333e+05         3          2         1460
# 4597  09-07-2014 00:00  4.169042e+05         3          2         3010
# 4598  10-07-2014 00:00  2.034000e+05         4          2         2090
# 4599  10-07-2014 00:00  2.206000e+05         3          2         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df["price"].mean()
# Out:
# 551962.9884730439

# %%
df["price"].std()
# Out:
# 563834.7025468111

# %%
plt.hist(df["price"])
plt.show()

# %%
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['bedrooms'])
plt.subplot(1,2,2)
sns.distplot(df['bathrooms'])
plt.show()

# %%
t=df['condition']
plt.boxplot(t)
plt.show()

# %%
from sklearn.model_selection import train_test_split
x=df.iloc[:,1:]
y=df['price']
print(x)
print(y)
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.20, random_state=1)
# Out:
#              price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0     3.130000e+05         
# ...

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,predictt))
# Out:
# 9.117120813055976e-20

# %%
age_of_building=2022-df["yr_built"]
print(age_of_building)
# Out:
# 0        67
# 1       101
# 2        56
# 3        59
# 4        46
#        ...
# 4595     68
# 4596     39
# 4597     13
# 4598     48
# 4599     32
# Name: yr_built, Length: 4600, dtype: int64

# %%
buildings_age=2022-df["yr_renovated"]
print(buildings_age)
# Out:
# 0         17
# 1       2022
# 2       2022
# 3       2022
# 4         30
#         ...
# 4595      43
# 4596      13
# 4597    2022
# 4598    2022
# 4599    2022
# Name: yr_renovated, Length: 4600, dtype: int64

# %%
buildings_age.replace(2022,0,inplace=True)

# %%
df = df.assign(age_buil=buildings_age)
df
# Out:
#                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3          1         1340
# 1     02-05-2014 00:00  2.384000e+06         5          2         3650
# 2     02-05-2014 00:00  3.420000e+05         3          2         1930
# 3     02-05-2014 00:00  4.200000e+05         3          2         2000
# 4     02-05-2014 00:00  5.500000e+05         4          2         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3          1         1510
# 4596  09-07-2014 00:00  5.343333e+05         3          2         1460
# 4597  09-07-2014 00:00  4.169042e+05         3          2         3010
# 4598  10-07-2014 00:00  2.034000e+05         4          2         2090
# 4599  10-07-2014 00:00  2.206000e+05         3          2         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df=df.drop(["yr_built","yr_renovated"],axis=1)

# %%
print(df)
# Out:
#                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3          1         1340
# 1     02-05-2014 00:00  2.384000e+06         5          2         3650
# 2     02-05-2014 00:00  3.420000e+05         3          2         1930
# 3     02-05-2014 00:00  4.200000e+05         3          2         2000
# 4     02-05-2014 00:00  5.500000e+05         4          2         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3          1         1510
# 4596  09-07-2014 00:00  5.343333e+05         3          2         1460
# 4597  09-07-2014 00:00  4.169042e+05         3          2         3010
# 4598  10-07-2014 00:00  2.034000e+05         4          2         2090
# 4599  10-07-2014 00:00  2.206000e+05         3          2         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df['price'].value_counts().plot(kind='bar')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
from sklearn.ensemble import RandomForestRegressor
model1=RandomForestRegressor(n_estimators=100, random_state=0)
model1.fit(x_train,y_train)
# Out:
# RandomForestRegressor(random_state=0)

# %%
y_pred= model1.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error
print(mean_squared_error(y_test,y_pred))
# Out:
# 595346871.3940445

# %%
x_train.shape
# Out:
# (3680, 13)

# %%
y_train.shape
# Out:
# (3680,)

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import f1_score
def accuracy(model):
    model.fit(x_train,y_train)
    predict = model.predict(x_test)
    return y_test,predict

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.cluster import KMeans
from sklearn.ensemble import AdaBoostRegressor

model2 = RandomForestRegressor()
model4 = LogisticRegression()
model5 = KNeighborsRegressor()
model6 = SGDRegressor()
model7 = DecisionTreeRegressor()




model8 = GaussianNB()
model9 = SVC()
model10= AdaBoostRegressor()
    
models=[model1,model2,model5,model6,model7,model10]
i=0
for model in models:
    i+=1
    y_test, predict=accuracy_score(model)
    print("Model ", i,":", model)
    print('mean_squared_error score:',mean_squared_error(y_test,predict))
    #print('F1 score:',f1_score(y_test, predict))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [466], in <cell line: 28>()
#      28 for model in models:
#      29     i+=1
# ---> 30     y_test, predict=accuracy_score(model)
#      31     print("Model ", i,":", model)
#      32     print('mean_squared_error score:',mean_squared_error(y_test,predict))
#
# TypeError: accuracy_score() missing 1 required positional argument: 'y_pred'
